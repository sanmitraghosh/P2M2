# %%
from scipy.integrate import odeint
import math 
import numpy as np
import matplotlib.pyplot as plt
import theano
# %matplotlib inline

theano.config.compute_test_value = 'raise'
theano.config.exception_verbosity= 'high'
THEANO_FLAGS='floatX=float32,optimizer=fast_compile'
theano.config.floatX = 'float64'

# %% [markdown]
# In this example we will use PyMC3 to infer the parameters of the Fitzhugh-Nagumo oscillator. It is a simple model that
# generates action potentials. The model is describes as:
#
# \begin{align}
# \frac{dV}{dt}&=(V - \frac{V^3}{3} + R)c\\
# \frac{dR}{dt}&=\frac{-(V-a+bR)}{c},
# \end{align}
# where $a$, $b$, $c$ are the model parameters.
#
# We start by defining our ODE solver. In this case we will be using scipy odeint. However, note that we can also wrapp any other solver written in say C++. The point I am trying to drive home is that we are free to call up any model solver as long as it is available in python.

# %%
def model_deriv(y, t, param):
    #Define parameters
    a,b,c=param
    
    #define states
    V,R=y
    #define derivatives
    dV_dt=(V-((V**3)/3) +R)*c
    dR_dt=-(V-a+b*R)/c
    return dV_dt,dR_dt
    
def model_sol(param):
    
    y0 = [-1,1]
    time = np.linspace(0, 20, 200)
    solution = odeint(model_deriv, y0, time, args=(param,))
    return np.array(solution)

# %% [markdown]
# Having defined our model solver and forward solution, we can generate some synthetic data. We solve the model between [0,20] with 200 equispaced time points and add Gaussian noise with $\sigma=0.5$.

# %%
time = np.linspace(0, 20, 200)
sigma=0.5
sol=model_sol([0.2,0.2,3.])
Y=sol+np.random.randn(200,2)*sigma
plt.plot(time,Y,linestyle='None',marker='o',markersize=2)
plt.plot(time,sol,linewidth=3.5)
# Out:
# [<matplotlib.lines.Line2D at 0x2ad8efd4d68>,
#  <matplotlib.lines.Line2D at 0x2ad934ec320>]

# %% [markdown]
# This is perhaps the most important pat of this example. Here we are defining a custom Theano as_op. Note that we are
# wrapping up the forward solution of our model as an as_op. Thus we tell Theano that we have three parameters each
# being a Theano scalar. The output then is a Theano matrix whose colums are the state vectors.

# %%
import theano.tensor as tt
from theano.compile.ops import as_op

@as_op(itypes=[tt.dscalar,tt.dscalar,tt.dscalar], otypes=[tt.dmatrix])
def lotka_ode_sol(param1,param2,param3):
    
    param=[param1,param2,param3]
    sol=model_sol(param)
    
    return sol

# %% [markdown]
# Next we define the probabilistic program. The likelihood is a multivariate Normal distribution. The priors are set as follows:
# $a\sim \mathcal{\Gamma}(2,1)$, $b\sim \mathcal{N}(0,1)$ and $c\sim \mathcal{U}(0,10)$. In this example we will be estimating the noise standard deviation and thus we put the following prior: $\sigma\sim \mathcal{N}(0,1)$.

# %%
import pymc3 as pm
from pymc3.step_methods import smc
from tempfile import mkdtemp
from scipy import optimize
basic_model = pm.Model()
n_steps = 20 # Number of MCMC steps for each particle
n_chains = 50 # Number of particles (chains)

with basic_model:

    # Priors for unknown model parameters
    
    
    a = pm.Gamma('a', alpha=2,beta=1, transform=None)
    b = pm.Normal('b', mu=0, sd=1)
    c = pm.Uniform('c', lower=0, upper=10, transform=None)
    sigma = pm.Normal('sigma', mu=0, sd=1)


    # Forward model
    
    mu = lotka_ode_sol(a,b,c)
    
    # Likelihood (sampling distribution) of observations
    cov=np.eye(2)*sigma**2
    Y_obs = pm.MvNormal('Y_obs', mu=mu, cov=cov, observed=Y)

    
    test_folder = mkdtemp(prefix='SMC_TEST')
    
     # Initial points for each of the chains
    start=[{'a':np.random.uniform(0,15,1),'b':np.random.uniform(0,15,1),
            'c':np.random.uniform(0,15,1),'sigma':np.random.uniform(0,2)} for _ in range(n_chains)]
    
    # Call SMC sampler
    trace = smc.sample_smc(n_steps=n_steps,n_chains=n_chains,start=start,progressbar=True,
                           homepath=test_folder,
                           stage=0,tune_interval=5,random_seed=21)
# Out:
# C:\Users\sanmi\Anaconda3\lib\site-packages\pymc3\step_methods\smc.py:480: UserWarning: Warning: SMC is an experimental step method, and not yet recommended for use in PyMC3!
#   warnings.warn(EXPERIMENTAL_WARNING)
# Argument `step` is None. Auto-initialising step object using given/default parameters.
# C:\Users\sanmi\Anaconda3\lib\site-packages\pymc3\step_methods\smc.py:120: UserWarning: Warning: SMC is an experimental step method, and not yet recommended for use in PyMC3!
#   warnings.warn(EXPERIMENTAL_WARNING)
# Adding model likelihood to RVs!
# Init new trace!
# Sample initial stage: ...
# Beta: 0.000000 Stage: 0
# Initialising chain traces ...
# Sampling ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 135.24it/s]
# Beta: 0.000319 Stage: 1
# Initialising chain traces ...
# Sampling ...
#   8%|██████▋                                                                            | 4/50 [00:00<00:03, 14.12it/s]C:\Users\sanmi\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.63it/s]
# Beta: 0.006928 Stage: 2
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.62it/s]
# Beta: 0.020366 Stage: 3
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.75it/s]
# Beta: 0.037341 Stage: 4
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.32it/s]
# Beta: 0.045548 Stage: 5
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:06<00:00,  7.47it/s]
# Beta: 0.053709 Stage: 6
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:08<00:00,  6.35it/s]
# Beta: 0.063835 Stage: 7
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  5.61it/s]
# Beta: 0.087363 Stage: 8
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.83it/s]
# Beta: 0.156650 Stage: 9
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.81it/s]
# Beta: 0.322966 Stage: 10
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.69it/s]
# Beta: 0.742005 Stage: 11
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.73it/s]
# Beta > 1.: 1.437639
# Sample final stage
# Initialising chain traces ...
# Sampling ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.52it/s]

# %%
pm.plot_posterior(trace)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99C42390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9A408BE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99C51FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9A166BA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9A1B4908>], dtype=object)

# %%
summary=pm.df_summary(trace, ['a'])
a=summary['mean']
summary=pm.df_summary(trace, ['b'])
b=summary['mean']
summary=pm.df_summary(trace, ['c'])
c=summary['mean']
est_sol=model_sol([a['a'],b['b'],c['c']])
plt.subplot(2,1,1)
plt.plot(time,Y[:,0],label='Data',linestyle='None',marker='o')
plt.plot(time,est_sol[:,0],color='k',linewidth=2.5,label='Fit')
plt.plot(time,sol[:,0],linestyle='--',label='True')
plt.legend(loc='upper right',fontsize='10')

plt.subplot(2,1,2)
plt.plot(time,Y[:,1],linestyle='None',marker='o')
plt.plot(time,est_sol[:,1],color='k',linewidth=2.5)
plt.plot(time,sol[:,1],linestyle='--')

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD90AFAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD974934E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD97548710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9751C3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99AA2B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99B51C88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99B4ECC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD99FCE978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9A02E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AD9A7AB7B8>]], dtype=object)

# %%
basic_model.marginal_likelihood
# Out:
# 3.6149529030398532e-08
